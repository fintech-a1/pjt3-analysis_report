# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr

# %%
df = pd.read_csv('close_return6m_1y.csv', index_col=0, dtype={'code':str})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#                작성일         개장일         상장일 Market    Name    code  \
# 0       2021-11-03  2021-11-03  2021-08-06  ^KS11   카카오뱅크  323410
# 1       2021-11-03  2021-11-03  2021-08-06  ^KS11   카카오뱅크  323410
# 2       2021-11-03  2021-11-03  2021-08-06  ^KS11   카카오뱅크  323410
# 3       2021-10-18  2021-10-18  2021-08-06  ^KS11   카카오뱅크  323410
# 4       2021-10-12  2021-10-12  2021-08-06  ^KS11   카카오뱅크  323410
# ...            ...         ...         ...    ...     ...     ...
# 125951  2012-02-17  2012-02-17  2009-07-28  ^KQ11    동일금속  109860
# 125952  2012-02-03  2012-02-03  2009-07-28  ^KQ11    동일금속  109860
# 125953  2011-11-28  2011-11-28  2003-06-11  ^KQ11    홈캐스트  064240
# 125954  2011-11-24  2011-11-24  2009-05-19  ^KQ11     SDN  099220
# 125955  2011-11-16  2011-11-16  2011-06-14  ^KQ11  스카이이앤엠  131100
#
#                   Sector   목표주가     Close  \
# 0              은행 및 저축기관      0   59400.0
# 1              은행 및 저축기관  81000   59400.0
# 2              은행 및 저축기관  73000   59400.0
# ...

# %%
df.columns
# Out:
# Index(['작성일', '개장일', '상장일', 'Market', 'Name', 'code', 'Sector', '목표주가',
#        'Close', '투자의견', '작성자', '제공출처', 'idx', '6month', 'Index_return_6',
#        'Index_return_1Y', '6month_개장일', 'Close_6month', '1year', '1year_개장일',
#        'Close_1Year'],
#       dtype='object')

# %%
df1 = df.copy()

# %%
df1=df1[['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'Close', '목표주가', 
         '6month', '6month_개장일', 'Index_return_6','Close_6month', '1year',
       '1year_개장일', 'Index_return_1Y','Close_1Year', '투자의견','idx','작성자', '제공출처']]

# %%
df1.drop(['6month','1year'],axis=1, inplace=True)

# %%
df1
# Out:
#                작성일         개장일 Market    Name    code            Sector  \
# 0       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 1       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 2       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 3       2021-10-18  2021-10-18  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 4       2021-10-12  2021-10-12  ^KS11   카카오뱅크  323410         은행 및 저축기관
# ...            ...         ...    ...     ...     ...               ...
# 125951  2012-02-17  2012-02-17  ^KQ11    동일금속  109860            금속 주조업
# 125952  2012-02-03  2012-02-03  ^KQ11    동일금속  109860            금속 주조업
# 125953  2011-11-28  2011-11-28  ^KQ11    홈캐스트  064240     영상 및 음향기기 제조업
# 125954  2011-11-24  2011-11-24  ^KQ11     SDN  099220  기계장비 및 관련 물품 도매업
# 125955  2011-11-16  2011-11-16  ^KQ11  스카이이앤엠  131100         상품 종합 도매업
#
#            Close   목표주가  6month_개장일       Index_return_6  Close_6month  \
# ...

# %%
df1.rename(columns={'Close':'adjusted_Close','목표주가':'report_TargetPrice',
                   'Close_6month':'6month_Close','Close_1Year':'1Year_Close'},inplace=True)

# %%
df1
# Out:
#                작성일         개장일 Market    Name    code            Sector  \
# 0       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 1       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 2       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 3       2021-10-18  2021-10-18  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 4       2021-10-12  2021-10-12  ^KS11   카카오뱅크  323410         은행 및 저축기관
# ...            ...         ...    ...     ...     ...               ...
# 125951  2012-02-17  2012-02-17  ^KQ11    동일금속  109860            금속 주조업
# 125952  2012-02-03  2012-02-03  ^KQ11    동일금속  109860            금속 주조업
# 125953  2011-11-28  2011-11-28  ^KQ11    홈캐스트  064240     영상 및 음향기기 제조업
# 125954  2011-11-24  2011-11-24  ^KQ11     SDN  099220  기계장비 및 관련 물품 도매업
# 125955  2011-11-16  2011-11-16  ^KQ11  스카이이앤엠  131100         상품 종합 도매업
#
#         adjusted_Close  report_TargetPrice  6month_개장일       Index_return_6  \
# ...

# %%
df1.insert(8,'액면비율', np.nan)

# %%
df1.insert(8, 'adjusted_Open', np.nan)

# %%
df1
# Out:
#                작성일         개장일 Market    Name    code            Sector  \
# 0       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 1       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 2       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 3       2021-10-18  2021-10-18  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 4       2021-10-12  2021-10-12  ^KS11   카카오뱅크  323410         은행 및 저축기관
# ...            ...         ...    ...     ...     ...               ...
# 125951  2012-02-17  2012-02-17  ^KQ11    동일금속  109860            금속 주조업
# 125952  2012-02-03  2012-02-03  ^KQ11    동일금속  109860            금속 주조업
# 125953  2011-11-28  2011-11-28  ^KQ11    홈캐스트  064240     영상 및 음향기기 제조업
# 125954  2011-11-24  2011-11-24  ^KQ11     SDN  099220  기계장비 및 관련 물품 도매업
# 125955  2011-11-16  2011-11-16  ^KQ11  스카이이앤엠  131100         상품 종합 도매업
#
#         adjusted_Close  report_TargetPrice  adjusted_Open  액면비율  6month_개장일  \
# ...

# %%
df1.insert(8,'adjusted_TargetPrice', np.nan)

# %%
df1.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Close',
#        'report_TargetPrice', 'adjusted_TargetPrice', 'adjusted_Open', '액면비율',
#        '6month_개장일', 'Index_return_6', '6month_Close', '1year_개장일',
#        'Index_return_1Y', '1Year_Close', '투자의견', 'idx', '작성자', '제공출처'],
#       dtype='object')

# %%
df1.insert(14, '6month_return', (df1['6month_Close'] - df1['adjusted_Close'])/df1['adjusted_Close'])

# %%
df1.insert(15, '6month_log_return', np.log(df1['6month_Close']/df1['adjusted_Close']))

# %%
df1.insert(18, '1Year_return', (df1['1Year_Close'] - df1['adjusted_Close'])/df1['adjusted_Close'])

# %%
df1.insert(19, '1Year_log_return', np.log(df1['1Year_Close']/df1['adjusted_Close']))

# %%
df1.insert(10, '괴리율', (df1['adjusted_TargetPrice']-df1['adjusted_Open'])/df1['adjusted_Open'])

# %%
df1
# Out:
#                작성일         개장일 Market    Name    code            Sector  \
# 0       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 1       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 2       2021-11-03  2021-11-03  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 3       2021-10-18  2021-10-18  ^KS11   카카오뱅크  323410         은행 및 저축기관
# 4       2021-10-12  2021-10-12  ^KS11   카카오뱅크  323410         은행 및 저축기관
# ...            ...         ...    ...     ...     ...               ...
# 125951  2012-02-17  2012-02-17  ^KQ11    동일금속  109860            금속 주조업
# 125952  2012-02-03  2012-02-03  ^KQ11    동일금속  109860            금속 주조업
# 125953  2011-11-28  2011-11-28  ^KQ11    홈캐스트  064240     영상 및 음향기기 제조업
# 125954  2011-11-24  2011-11-24  ^KQ11     SDN  099220  기계장비 및 관련 물품 도매업
# 125955  2011-11-16  2011-11-16  ^KQ11  스카이이앤엠  131100         상품 종합 도매업
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# ...

# %%
df1.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Close',
#        'report_TargetPrice', 'adjusted_TargetPrice', 'adjusted_Open', '괴리율',
#        '액면비율', '6month_개장일', 'Index_return_6', '6month_Close', '6month_return',
#        '6month_log_return', '1year_개장일', 'Index_return_1Y', '1Year_return',
#        '1Year_log_return', '1Year_Close', '투자의견', 'idx', '작성자', '제공출처'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125671 entries, 0 to 125955
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   작성일                   125671 non-null  object
#  1   개장일                   125671 non-null  object
#  2   Market                125671 non-null  object
#  3   Name                  125671 non-null  object
#  4   code                  125671 non-null  object
#  5   Sector                125661 non-null  object
#  6   adjusted_Close        125671 non-null  float64
#  7   report_TargetPrice    125671 non-null  int64
#  8   adjusted_TargetPrice  0 non-null       float64
#  9   adjusted_Open         0 non-null       float64
#  10  괴리율                   0 non-null       float64
#  11  액면비율                  0 non-null       float64
#  12  6month_개장일            125671 non-null  object
#  13  Index_return_6        122117 non-null  object
# ...

# %% [markdown]
# ### sector

# %%
df1[df1.Sector.isnull()]
# Out:
#                작성일         개장일 Market      Name    code Sector  \
# 48691   2021-10-26  2021-10-26  ^KS11     LG화학우  051915    NaN
# 118945  2019-12-12  2019-12-12  ^KS11  CJ제일제당 우  097955    NaN
# 118946  2019-12-11  2019-12-11  ^KS11   LG생활건강우  051905    NaN
# 118947  2016-10-27  2016-10-27  ^KS11   LG생활건강우  051905    NaN
# 119407  2019-11-06  2019-11-06  ^KS11     대신증권우  003545    NaN
# 121076  2019-05-16  2019-05-16  ^KS11   NH투자증권우  005945    NaN
# 123253  2018-05-10  2018-05-10  ^KS11   아모레퍼시픽우  090435    NaN
# 123796  2017-11-28  2017-11-28  ^KS11     유한양행우  000105    NaN
# 125087  2016-08-05  2016-08-05  ^KS11     삼성전자우  005935    NaN
# 125232  2016-04-18  2016-04-18  ^KS11       DL우  000215    NaN
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 48691         400000.0             1150000                   NaN
# 118945        106500.0              370000                   NaN
# 118946        735000.0             1550000                   NaN
# ...

# %%
df1[df1['code'] == '051910'].head(1)
# Out:
#               작성일         개장일 Market  Name    code       Sector  \
# 46286  2021-10-26  2021-10-26  ^KS11  LG화학  051910  기초 화학물질 제조업
#
#        adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 46286        830000.0              980000                   NaN
#
#        adjusted_Open  괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  \
# 46286            NaN  NaN   NaN  2022-04-22            NaN           NaN
#
#        6month_return  6month_log_return   1year_개장일 Index_return_1Y  \
# 46286            NaN                NaN  2022-10-26             NaN
#
#        1Year_return  1Year_log_return  1Year_Close  \
# 46286           NaN               NaN          NaN
#
#                                       투자의견     idx  작성자    제공출처
# 46286  Buy                                  599726  전우제  한화투자증권

# %%
df1.loc[df1.code == '051915', 'Sector'] = '기초 화학물질 제조업'

# %%
df1.loc[df1.Name == 'LG화학우']
# Out:
#               작성일         개장일 Market   Name    code       Sector  \
# 48691  2021-10-26  2021-10-26  ^KS11  LG화학우  051915  기초 화학물질 제조업
#
#        adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 48691        400000.0             1150000                   NaN
#
#        adjusted_Open  괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  \
# 48691            NaN  NaN   NaN  2022-04-22            NaN           NaN
#
#        6month_return  6month_log_return   1year_개장일 Index_return_1Y  \
# 48691            NaN                NaN  2022-10-26             NaN
#
#        1Year_return  1Year_log_return  1Year_Close  \
# 48691           NaN               NaN          NaN
#
#                                       투자의견     idx  작성자    제공출처
# 48691  Buy                                  599678  황성현  유진투자증권

# %%
df1.loc[df1.code == '097950'].head(1)
# Out:
#               작성일         개장일 Market    Name    code     Sector  \
# 64449  2021-10-18  2021-10-18  ^KS11  CJ제일제당  097950  기타 식품 제조업
#
#        adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 64449        410000.0              610000                   NaN
#
#        adjusted_Open  괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  \
# 64449            NaN  NaN   NaN  2022-04-15            NaN           NaN
#
#        6month_return  6month_log_return   1year_개장일 Index_return_1Y  \
# 64449            NaN                NaN  2022-10-18             NaN
#
#        1Year_return  1Year_log_return  1Year_Close  \
# 64449           NaN               NaN          NaN
#
#                                       투자의견     idx  작성자   제공출처
# 64449  Buy                                  599270  김정욱  메리츠증권

# %%
df1.loc[df1.Name == 'CJ제일제당 우', 'Sector'] = '기타 식품 제조업'

# %%
df1.loc[df1.Name == 'CJ제일제당 우']
# Out:
#                작성일         개장일 Market      Name    code     Sector  \
# 118945  2019-12-12  2019-12-12  ^KS11  CJ제일제당 우  097955  기타 식품 제조업
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 118945        106500.0              370000                   NaN
#
#         adjusted_Open  괴리율  액면비율  6month_개장일      Index_return_6  \
# 118945            NaN  NaN   NaN  2020-06-09  2.4127925638059766
#
#         6month_Close  6month_return  6month_log_return   1year_개장일  \
# 118945      131500.0       0.234742           0.210862  2020-12-11
#
#            Index_return_1Y  1Year_return  1Year_log_return  1Year_Close  \
# 118945  29.602542027686972      0.530516          0.425605     163000.0
#
#                                        투자의견     idx       작성자    제공출처
# 118945  Buy                                  546233  심은주, 권중하  하나금융투자

# %%
df1[df1['code'] == '051900'].head(1)
# Out:
#               작성일         개장일 Market    Name    code       Sector  \
# 40850  2021-10-27  2021-10-27  ^KS11  LG생활건강  051900  기타 화학제품 제조업
#
#        adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 40850       1221000.0             1650000                   NaN
#
#        adjusted_Open  괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  \
# 40850            NaN  NaN   NaN  2022-04-25            NaN           NaN
#
#        6month_return  6month_log_return   1year_개장일 Index_return_1Y  \
# 40850            NaN                NaN  2022-10-27             NaN
#
#        1Year_return  1Year_log_return  1Year_Close  \
# 40850           NaN               NaN          NaN
#
#                                       투자의견     idx  작성자     제공출처
# 40850  Buy                                  599823  허제나  카카오페이증권

# %%
df1.loc[df1.code == '051905', 'Sector'] = '기타 화학제품 제조업'

# %%
df1.loc[df1.code == '051905']
# Out:
#                작성일         개장일 Market     Name    code       Sector  \
# 118946  2019-12-11  2019-12-11  ^KS11  LG생활건강우  051905  기타 화학제품 제조업
# 118947  2016-10-27  2016-10-27  ^KS11  LG생활건강우  051905  기타 화학제품 제조업
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 118946        735000.0             1550000                   NaN
# 118947        470000.0             1100000                   NaN
#
#         adjusted_Open  괴리율  액면비율  6month_개장일      Index_return_6  \
# 118946            NaN  NaN   NaN  2020-06-08  3.7361877972594826
# 118947            NaN  NaN   NaN  2017-04-25   8.533590051762818
#
#         6month_Close  6month_return  6month_log_return   1year_개장일  \
# 118946      733000.0      -0.002721          -0.002725  2020-12-10
# 118947      529000.0       0.125532           0.118256  2017-10-27
#
#            Index_return_1Y  1Year_return  1Year_log_return  1Year_Close  \
# 118946  30.434732196896785     -0.051701         -0.053085     697000.0
# ...

# %%
df1[df1.Sector.isnull()]
# Out:
#                작성일         개장일 Market     Name    code Sector  adjusted_Close  \
# 119407  2019-11-06  2019-11-06  ^KS11    대신증권우  003545    NaN          9490.0
# 121076  2019-05-16  2019-05-16  ^KS11  NH투자증권우  005945    NaN          9000.0
# 123253  2018-05-10  2018-05-10  ^KS11  아모레퍼시픽우  090435    NaN        168500.0
# 123796  2017-11-28  2017-11-28  ^KS11    유한양행우  000105    NaN         29162.0
# 125087  2016-08-05  2016-08-05  ^KS11    삼성전자우  005935    NaN         25940.0
# 125232  2016-04-18  2016-04-18  ^KS11      DL우  000215    NaN         26673.0
#
#         report_TargetPrice  adjusted_TargetPrice  adjusted_Open  괴리율  액면비율  \
# 119407               12400                   NaN            NaN  NaN   NaN
# 121076               18000                   NaN            NaN  NaN   NaN
# 123253              400000                   NaN            NaN  NaN   NaN
# 123796              280000                   NaN            NaN  NaN   NaN
# ...

# %%
df1[df1['code'] == '003540'].head(1)
# Out:
#               작성일         개장일 Market  Name    code      Sector  \
# 54973  2021-10-25  2021-10-25  ^KS11  대신증권  003540  금융 지원 서비스업
#
#        adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 54973         20750.0               75000                   NaN
#
#        adjusted_Open  괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  \
# 54973            NaN  NaN   NaN  2022-04-22            NaN           NaN
#
#        6month_return  6month_log_return   1year_개장일 Index_return_1Y  \
# 54973            NaN                NaN  2022-10-25             NaN
#
#        1Year_return  1Year_log_return  1Year_Close  \
# 54973           NaN               NaN          NaN
#
#                                       투자의견     idx      작성자  제공출처
# 54973  Buy                                  599576  이동헌,이태환  대신증권

# %%
df1.loc[df1.code == '003545', 'Sector'] = '금융 지원 서비스업'

# %%
df1.loc[df1.code == '003545']
# Out:
#                작성일         개장일 Market   Name    code      Sector  \
# 119407  2019-11-06  2019-11-06  ^KS11  대신증권우  003545  금융 지원 서비스업
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 119407          9490.0               12400                   NaN
#
#         adjusted_Open  괴리율  액면비율  6month_개장일      Index_return_6  \
# 119407            NaN  NaN   NaN  2020-05-04  -11.60272921938077
#
#         6month_Close  6month_return  6month_log_return   1year_개장일  \
# 119407        8410.0      -0.113804          -0.120817  2020-11-05
#
#            Index_return_1Y  1Year_return  1Year_log_return  1Year_Close  \
# 119407  12.575619662786108      0.064278          0.062297      10100.0
#
#                                        투자의견     idx  작성자  제공출처
# 119407  Buy                                  542832  구경회  SK증권

# %%
df1[df1['code'] == '005940'].head(1)
# Out:
#               작성일         개장일 Market    Name    code      Sector  \
# 54614  2021-10-25  2021-10-25  ^KS11  NH투자증권  005940  금융 지원 서비스업
#
#        adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 54614         13250.0               15000                   NaN
#
#        adjusted_Open  괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  \
# 54614            NaN  NaN   NaN  2022-04-22            NaN           NaN
#
#        6month_return  6month_log_return   1year_개장일 Index_return_1Y  \
# 54614            NaN                NaN  2022-10-25             NaN
#
#        1Year_return  1Year_log_return  1Year_Close  \
# 54614           NaN               NaN          NaN
#
#                                       투자의견     idx  작성자   제공출처
# 54614  Buy                                  599580  정태준  유안타증권

# %%
df1.loc[df1.code == '005945', 'Sector'] = '금융 지원 서비스업'

# %%
df1.loc[df1.code == '005945']
# Out:
#                작성일         개장일 Market     Name    code      Sector  \
# 121076  2019-05-16  2019-05-16  ^KS11  NH투자증권우  005945  금융 지원 서비스업
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 121076          9000.0               18000                   NaN
#
#         adjusted_Open  괴리율  액면비율  6month_개장일      Index_return_6  \
# 121076            NaN  NaN   NaN  2019-11-12  3.5416325727708475
#
#         6month_Close  6month_return  6month_log_return   1year_개장일  \
# 121076        9130.0       0.014444           0.014341  2020-05-15
#
#            Index_return_1Y  1Year_return  1Year_log_return  1Year_Close  \
# 121076  -6.790665723018474     -0.204444         -0.228715       7160.0
#
#                                        투자의견     idx  작성자    제공출처
# 121076  Buy                                  524885  백두산  한국투자증권

# %%
df1[df1['code'] == '090430'].head(1)
# Out:
#              작성일         개장일 Market    Name    code       Sector  \
# 8568  2021-11-02  2021-11-02  ^KS11  아모레퍼시픽  090430  기타 화학제품 제조업
#
#       adjusted_Close  report_TargetPrice  adjusted_TargetPrice  adjusted_Open  \
# 8568        190500.0              195000                   NaN            NaN
#
#       괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  6month_return  \
# 8568  NaN   NaN  2022-04-29            NaN           NaN            NaN
#
#       6month_log_return   1year_개장일 Index_return_1Y  1Year_return  \
# 8568                NaN  2022-11-02             NaN           NaN
#
#       1Year_log_return  1Year_Close                                  투자의견  \
# 8568               NaN          NaN  Hold
#
#          idx  작성자   제공출처
# 8568  600256  박은정  유안타증권

# %%
df1.loc[df1.code == '090435', 'Sector'] = '기타 화학제품 제조업'

# %%
df1.loc[df1.code == '090435']
# Out:
#                작성일         개장일 Market     Name    code       Sector  \
# 123253  2018-05-10  2018-05-10  ^KS11  아모레퍼시픽우  090435  기타 화학제품 제조업
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 123253        168500.0              400000                   NaN
#
#         adjusted_Open  괴리율  액면비율  6month_개장일       Index_return_6  \
# 123253            NaN  NaN   NaN  2018-11-06  -15.199492252159096
#
#         6month_Close  6month_return  6month_log_return   1year_개장일  \
# 123253       95300.0      -0.434421          -0.569906  2019-05-10
#
#             Index_return_1Y  1Year_return  1Year_log_return  1Year_Close  \
# 123253  -14.451979000909422     -0.335312         -0.408437     112000.0
#
#                                       투자의견     idx  작성자    제공출처
# 123253  매수                                  476405  이지용  신한금융투자

# %%
df1[df1['code'] == '000100'].head(1)
# Out:
#              작성일         개장일 Market  Name    code   Sector  adjusted_Close  \
# 9854  2021-11-02  2021-11-02  ^KS11  유한양행  000100  의약품 제조업         61700.0
#
#       report_TargetPrice  adjusted_TargetPrice  adjusted_Open  괴리율  액면비율  \
# 9854               95000                   NaN            NaN  NaN   NaN
#
#       6month_개장일 Index_return_6  6month_Close  6month_return  \
# 9854  2022-04-29            NaN           NaN            NaN
#
#       6month_log_return   1year_개장일 Index_return_1Y  1Year_return  \
# 9854                NaN  2022-11-02             NaN           NaN
#
#       1Year_log_return  1Year_Close                                 투자의견  \
# 9854               NaN          NaN  Buy
#
#          idx      작성자  제공출처
# 9854  600238  임윤진,한송협  대신증권

# %%
df1.loc[df1.code == '000105', 'Sector'] = '의약품 제조업'

# %%
df1.loc[df1.code == '000105']
# Out:
#                작성일         개장일 Market   Name    code   Sector  adjusted_Close  \
# 123796  2017-11-28  2017-11-28  ^KS11  유한양행우  000105  의약품 제조업         29162.0
#
#         report_TargetPrice  adjusted_TargetPrice  adjusted_Open  괴리율  액면비율  \
# 123796              280000                   NaN            NaN  NaN   NaN
#
#         6month_개장일      Index_return_6  6month_Close  6month_return  \
# 123796  2018-05-25  -2.123542525520672       35953.0       0.232872
#
#         6month_log_return   1year_개장일      Index_return_1Y  1Year_return  \
# 123796           0.209346  2018-11-28  -16.147147994556676      0.235821
#
#         1Year_log_return  1Year_Close                                 투자의견  \
# 123796          0.211735      36039.0  Buy
#
#            idx  작성자     제공출처
# 123796  454473  이태영  메리츠종금증권

# %%
df1[df1['code'] == '005930'].head(1)
# Out:
#               작성일         개장일 Market  Name    code          Sector  \
# 17678  2021-11-01  2021-11-01  ^KS11  삼성전자  005930  통신 및 방송 장비 제조업
#
#        adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 17678         69900.0               89000                   NaN
#
#        adjusted_Open  괴리율  액면비율  6month_개장일 Index_return_6  6month_Close  \
# 17678            NaN  NaN   NaN  2022-04-29            NaN           NaN
#
#        6month_return  6month_log_return   1year_개장일 Index_return_1Y  \
# 17678            NaN                NaN  2022-11-01             NaN
#
#        1Year_return  1Year_log_return  1Year_Close  \
# 17678           NaN               NaN          NaN
#
#                                       투자의견     idx  작성자    제공출처
# 17678  Buy                                  600146  송명섭  하이투자증권

# %%
df1.loc[df1.code == '005935', 'Sector'] = '통신 및 방송 장비 제조업'

# %%
df1.loc[df1.code == '005935']
# Out:
#                작성일         개장일 Market   Name    code          Sector  \
# 125087  2016-08-05  2016-08-05  ^KS11  삼성전자우  005935  통신 및 방송 장비 제조업
#
#         adjusted_Close  report_TargetPrice  adjusted_TargetPrice  \
# 125087         25940.0             1730000                   NaN
#
#         adjusted_Open  괴리율  액면비율  6month_개장일      Index_return_6  \
# 125087            NaN  NaN   NaN  2017-02-01  3.0992022001862685
#
#         6month_Close  6month_return  6month_log_return   1year_개장일  \
# 125087       31300.0       0.206631           0.187832  2017-08-04
#
#           Index_return_1Y  1Year_return  1Year_log_return  1Year_Close  \
# 125087  18.70769302988018      0.448728          0.370686      37580.0
#
#                                       투자의견     idx  작성자     제공출처
# 125087  매수                                  388042  이승우  IBK투자증권

# %%
df1[df1['code'] == '000210'].head(1)
# Out:
#               작성일         개장일 Market Name    code  Sector  adjusted_Close  \
# 14474  2021-11-01  2021-11-01  ^KS11   DL  000210  기타 금융업         67200.0
#
#        report_TargetPrice  adjusted_TargetPrice  adjusted_Open  괴리율  액면비율  \
# 14474               93000                   NaN            NaN  NaN   NaN
#
#        6month_개장일 Index_return_6  6month_Close  6month_return  \
# 14474  2022-04-29            NaN           NaN            NaN
#
#        6month_log_return   1year_개장일 Index_return_1Y  1Year_return  \
# 14474                NaN  2022-11-01             NaN           NaN
#
#        1Year_log_return  1Year_Close                                 투자의견  \
# 14474               NaN          NaN  Buy
#
#           idx  작성자    제공출처
# 14474  600160  전우제  한화투자증권

# %%
df1.loc[df1.code == '000215', 'Sector'] = '기타 금융업'

# %%
df1.loc[df1.code == '000215']
# Out:
#                작성일         개장일 Market Name    code  Sector  adjusted_Close  \
# 125232  2016-04-18  2016-04-18  ^KS11  DL우  000215  기타 금융업         26673.0
#
#         report_TargetPrice  adjusted_TargetPrice  adjusted_Open  괴리율  액면비율  \
# 125232                   0                   NaN            NaN  NaN   NaN
#
#         6month_개장일      Index_return_6  6month_Close  6month_return  \
# 125232  2016-10-14  0.6749319973385237       25041.0      -0.061185
#
#         6month_log_return   1year_개장일     Index_return_1Y  1Year_return  \
# 125232          -0.063137  2017-04-18  6.9364385568179365     -0.086979
#
#         1Year_log_return  1Year_Close                               투자의견  \
# 125232         -0.090997      24353.0  -
#
#            idx  작성자  제공출처
# 125232  377284  이선일  대신증권

# %%
df1[df1.Sector.isnull()]
# Out:
# Empty DataFrame
# Columns: [작성일, 개장일, Market, Name, code, Sector, adjusted_Close, report_TargetPrice, adjusted_TargetPrice, adjusted_Open, 괴리율, 액면비율, 6month_개장일, Index_return_6, 6month_Close, 6month_return, 6month_log_return, 1year_개장일, Index_return_1Y, 1Year_return, 1Year_log_return, 1Year_Close, 투자의견, idx, 작성자, 제공출처]
# Index: []

# %% [markdown]
# ### KONEX

# %%
df1[df1.Market =='KONEX']
# Out:
#                작성일         개장일 Market      Name    code  \
# 108823  2021-06-14  2021-06-14  KONEX     프로테옴텍  303360
# 108824  2020-11-30  2020-11-30  KONEX     프로테옴텍  303360
# 108825  2020-06-11  2020-06-11  KONEX     프로테옴텍  303360
# 108826  2019-12-06  2019-12-06  KONEX     프로테옴텍  303360
# 108827  2021-06-14  2021-06-14  KONEX     테크트랜스  258050
# ...            ...         ...    ...       ...     ...
# 122024  2018-11-27  2018-11-27  KONEX    한중엔시에스  107640
# 122104  2018-11-14  2018-11-14  KONEX  에스에이티이엔지  158300
# 122792  2018-07-09  2018-07-09  KONEX       미애부  225850
# 122793  2018-07-09  2018-07-09  KONEX   비플라이소프트  148780
# 123053  2018-05-28  2018-05-28  KONEX       스템랩  258540
#
#                        Sector  adjusted_Close  report_TargetPrice  \
# 108823  의료용품 및 기타 의약 관련제품 제조업          7640.0                   0
# 108824  의료용품 및 기타 의약 관련제품 제조업         10900.0                   0
# 108825  의료용품 및 기타 의약 관련제품 제조업         15300.0                   0
# ...

# %%
konex_index = df1[df1.Market =='KONEX'].index.tolist()
df1.drop(konex_index, axis=0,inplace=True)

# %%
df1.isnull().sum()
# Out:
# 작성일                          0
# 개장일                          0
# Market                       0
# Name                         0
# code                         0
# Sector                       0
# adjusted_Close               0
# report_TargetPrice           0
# adjusted_TargetPrice    125555
# adjusted_Open           125555
# 괴리율                     125555
# 액면비율                    125555
# 6month_개장일                   0
# Index_return_6            3535
# 6month_Close              3535
# 6month_return             3535
# 6month_log_return         3535
# 1year_개장일                    0
# Index_return_1Y           8598
# 1Year_return              8598
# 1Year_log_return          8598
# 1Year_Close               8598
# 투자의견                         0
# idx                          0
# 작성자                          0
# 제공출처                         0
# dtype: int64

# %%
# 샘플링만 빠진 원본 데이터

# %%
df1.to_csv('origin_df_final.csv', encoding='utf-8-sig')

# %%
df1.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Close',
#        'report_TargetPrice', 'adjusted_TargetPrice', 'adjusted_Open', '괴리율',
#        '액면비율', '6month_개장일', 'Index_return_6', '6month_Close', '6month_return',
#        '6month_log_return', '1year_개장일', 'Index_return_1Y', '1Year_return',
#        '1Year_log_return', '1Year_Close', '투자의견', 'idx', '작성자', '제공출처'],
#       dtype='object')

# %%
# 샘플링 데이터

# %%
df_1 = pd.read_csv('standard_df_final.csv', index_col=0)

# %%
df_1.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Open',
#        'adjusted_Close', 'report_Open', 'report_Close', '괴리율',
#        'adjusted_TargetPrice', 'report_TargetPrice', '액면비율', 'Index_return_6',
#        'Index_return_1Y', '6month_개장일', '6month_return', '6month_log_return',
#        '6month_Close', '1year_개장일', '1Year_return', '1Year_log_return',
#        '1Year_Close', '투자의견', 'idx', '작성자', '제공출처'],
#       dtype='object')

# %%
df_1.isnull().sum()
# Out:
# 작성일                        0
# 개장일                        0
# Market                     0
# Name                       0
# code                       0
# Sector                     0
# adjusted_Open              0
# adjusted_Close             0
# report_Open                0
# report_Close               0
# 괴리율                        0
# adjusted_TargetPrice       0
# report_TargetPrice         0
# 액면비율                       0
# Index_return_6           631
# Index_return_1Y         1417
# 6month_개장일                 0
# 6month_return            631
# 6month_log_return        631
# 6month_Close             631
# 1year_개장일                  0
# 1Year_return            1417
# 1Year_log_return        1417
# 1Year_Close             1417
# 투자의견                       0
# idx                        0
# 작성자                        0
# 제공출처                       0
# dtype: int64

# %%
df_final=pd.concat([df1, df_1])

# %%
df_final
# Out:
#               작성일         개장일 Market   Name    code  \
# 0      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 1      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 2      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 3      2021-10-18  2021-10-18  ^KS11  카카오뱅크  323410
# 4      2021-10-12  2021-10-12  ^KS11  카카오뱅크  323410
# ...           ...         ...    ...    ...     ...
# 20288  2015-03-17  2015-03-17  ^KS11   사조산업    7160
# 20289  2015-06-12  2015-06-12  ^KS11  까뮤이앤씨   13700
# 20290  2015-06-01  2015-06-01  ^KQ11   서전기전  189860
# 20291  2015-03-17  2015-03-17  ^KQ11   서전기전  189860
# 20292  2014-07-14  2014-07-14  ^KQ11     협진  138360
#
#                                   Sector  adjusted_Close  report_TargetPrice  \
# 0                              은행 및 저축기관         59400.0                   0
# 1                              은행 및 저축기관         59400.0               81000
# 2                              은행 및 저축기관         59400.0               73000
# ...

# %%
df_final.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Close',
#        'report_TargetPrice', 'adjusted_TargetPrice', 'adjusted_Open', '괴리율',
#        '액면비율', '6month_개장일', 'Index_return_6', '6month_Close', '6month_return',
#        '6month_log_return', '1year_개장일', 'Index_return_1Y', '1Year_return',
#        '1Year_log_return', '1Year_Close', '투자의견', 'idx', '작성자', '제공출처',
#        'report_Open', 'report_Close'],
#       dtype='object')

# %%
df_1.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Open',
#        'adjusted_Close', 'report_Open', 'report_Close', '괴리율',
#        'adjusted_TargetPrice', 'report_TargetPrice', '액면비율', 'Index_return_6',
#        'Index_return_1Y', '6month_개장일', '6month_return', '6month_log_return',
#        '6month_Close', '1year_개장일', '1Year_return', '1Year_log_return',
#        '1Year_Close', '투자의견', 'idx', '작성자', '제공출처'],
#       dtype='object')

# %%
df_final=df_final[['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Open',
       'adjusted_Close', 'report_Open', 'report_Close', '괴리율',
       'adjusted_TargetPrice', 'report_TargetPrice', '액면비율', 'Index_return_6',
       'Index_return_1Y', '6month_개장일', '6month_return', '6month_log_return',
       '6month_Close', '1year_개장일', '1Year_return', '1Year_log_return',
       '1Year_Close', '투자의견', 'idx', '작성자', '제공출처']]

# %%
df_final.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Open',
#        'adjusted_Close', 'report_Open', 'report_Close', '괴리율',
#        'adjusted_TargetPrice', 'report_TargetPrice', '액면비율', 'Index_return_6',
#        'Index_return_1Y', '6month_개장일', '6month_return', '6month_log_return',
#        '6month_Close', '1year_개장일', '1Year_return', '1Year_log_return',
#        '1Year_Close', '투자의견', 'idx', '작성자', '제공출처'],
#       dtype='object')

# %%
df_final.to_csv('origin_sample_concat_df_final.csv', encoding ='utf-8-sig')

# %%
df_final.isnull().sum()
# Out:
# 작성일                          0
# 개장일                          0
# Market                       0
# Name                         0
# code                         0
# Sector                       0
# adjusted_Open           125555
# adjusted_Close               0
# report_Open             125555
# report_Close            125555
# 괴리율                     125555
# adjusted_TargetPrice    125555
# report_TargetPrice           0
# 액면비율                    125555
# Index_return_6            4166
# Index_return_1Y          10015
# 6month_개장일                   0
# 6month_return             4166
# 6month_log_return         4166
# 6month_Close              4166
# 1year_개장일                    0
# 1Year_return             10015
# 1Year_log_return         10015
# 1Year_Close              10015
# 투자의견                         0
# idx                          0
# 작성자                          0
# 제공출처                         0
# dtype: int64

# %%
df_final.head()
# Out:
#           작성일         개장일 Market   Name    code     Sector  adjusted_Open  \
# 0  2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410  은행 및 저축기관            NaN
# 1  2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410  은행 및 저축기관            NaN
# 2  2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410  은행 및 저축기관            NaN
# 3  2021-10-18  2021-10-18  ^KS11  카카오뱅크  323410  은행 및 저축기관            NaN
# 4  2021-10-12  2021-10-12  ^KS11  카카오뱅크  323410  은행 및 저축기관            NaN
#
#    adjusted_Close  report_Open  report_Close  괴리율  adjusted_TargetPrice  \
# 0         59400.0          NaN           NaN  NaN                   NaN
# 1         59400.0          NaN           NaN  NaN                   NaN
# 2         59400.0          NaN           NaN  NaN                   NaN
# 3         60000.0          NaN           NaN  NaN                   NaN
# 4         55300.0          NaN           NaN  NaN                   NaN
#
#    report_TargetPrice  액면비율 Index_return_6 Index_return_1Y  6month_개장일  \
# ...

# %%
df_final.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Open',
#        'adjusted_Close', 'report_Open', 'report_Close', '괴리율',
#        'adjusted_TargetPrice', 'report_TargetPrice', '액면비율', 'Index_return_6',
#        'Index_return_1Y', '6month_개장일', '6month_return', '6month_log_return',
#        '6month_Close', '1year_개장일', '1Year_return', '1Year_log_return',
#        '1Year_Close', '투자의견', 'idx', '작성자', '제공출처'],
#       dtype='object')

# %%
df_final_mod = df_final.drop(['adjusted_Open','report_Open','report_Close','괴리율','adjusted_TargetPrice','액면비율'], axis=1)

# %%
df_final_mod.isnull().sum()
# Out:
# 작성일                       0
# 개장일                       0
# Market                    0
# Name                      0
# code                      0
# Sector                    0
# adjusted_Close            0
# report_TargetPrice        0
# Index_return_6         4166
# Index_return_1Y       10015
# 6month_개장일                0
# 6month_return          4166
# 6month_log_return      4166
# 6month_Close           4166
# 1year_개장일                 0
# 1Year_return          10015
# 1Year_log_return      10015
# 1Year_Close           10015
# 투자의견                      0
# idx                       0
# 작성자                       0
# 제공출처                      0
# dtype: int64

# %%
df_final_mod.to_csv('origin_sample_concat_df_final_mod.csv', encoding='utf-8-sig')

# %%
df_final_mod['Index_return_6'] = df_final_mod['Index_return_6'].astype('float')

# %%
df_final_mod['Index_return_1Y'] = df_final_mod['Index_return_1Y'].astype('float')

# %%
df_final_mod['code'] = df_final_mod.code.apply(lambda x : str(x).zfill(6))
df_final_mod['Index_return_6'] = df_final_mod['Index_return_6']/100
df_final_mod['Index_return_1Y'] = df_final_mod['Index_return_1Y']/100
df_final_mod.insert(17, '6month_return_index', df_final_mod['6month_return'] - df_final_mod['Index_return_6'])
df_final_mod.insert(22, '1Year_return_index', df_final_mod['1Year_return'] - df_final_mod['Index_return_1Y'])
df_final_mod
# Out:
#               작성일         개장일 Market   Name    code  \
# 0      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 1      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 2      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 3      2021-10-18  2021-10-18  ^KS11  카카오뱅크  323410
# 4      2021-10-12  2021-10-12  ^KS11  카카오뱅크  323410
# ...           ...         ...    ...    ...     ...
# 20288  2015-03-17  2015-03-17  ^KS11   사조산업  007160
# 20289  2015-06-12  2015-06-12  ^KS11  까뮤이앤씨  013700
# 20290  2015-06-01  2015-06-01  ^KQ11   서전기전  189860
# 20291  2015-03-17  2015-03-17  ^KQ11   서전기전  189860
# 20292  2014-07-14  2014-07-14  ^KQ11     협진  138360
#
#                                   Sector  adjusted_Close  report_TargetPrice  \
# 0                              은행 및 저축기관         59400.0                   0
# 1                              은행 및 저축기관         59400.0               81000
# 2                              은행 및 저축기관         59400.0               73000
# ...

# %%
df_final_mod['6month_return']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 20288    0.014013
# 20289   -0.004049
# 20290   -0.319101
# 20291   -0.226148
# 20292   -0.102488
# Name: 6month_return, Length: 145751, dtype: float64

# %%
df_final_mod.columns
# Out:
# Index(['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Close',
#        'report_TargetPrice', 'Index_return_6', 'Index_return_1Y', '6month_개장일',
#        '6month_return', '6month_log_return', '6month_Close', '1year_개장일',
#        '1Year_return', '1Year_log_return', '6month_return_index',
#        '1Year_Close', '투자의견', 'idx', '작성자', '1Year_return_index', '제공출처'],
#       dtype='object')

# %%
df_final_mod = df_final_mod[['작성일', '개장일', 'Market', 'Name', 'code', 'Sector', 'adjusted_Close',
       'report_TargetPrice', 'Index_return_6', 'Index_return_1Y', '6month_개장일','6month_return_index',
       '6month_return', '6month_log_return', '6month_Close', '1year_개장일','1Year_return_index', 
       '1Year_return', '1Year_log_return', 
       '1Year_Close', '투자의견', 'idx', '작성자', '제공출처']]

# %%
df_final_mod.isnull().sum()
# Out:
# 작성일                        0
# 개장일                        0
# Market                     0
# Name                       0
# code                       0
# Sector                     0
# adjusted_Close             0
# report_TargetPrice         0
# Index_return_6          4166
# Index_return_1Y        10015
# 6month_개장일                 0
# 6month_return_index     4166
# 6month_return           4166
# 6month_log_return       4166
# 6month_Close            4166
# 1year_개장일                  0
# 1Year_return_index     10015
# 1Year_return           10015
# 1Year_log_return       10015
# 1Year_Close            10015
# 투자의견                       0
# idx                        0
# 작성자                        0
# 제공출처                       0
# dtype: int64

# %%
df_final_mod.to_csv('origin_sample_concat_df_final_mod2.csv', encoding='utf-8-sig')

# %%
df_final_mod
# Out:
#               작성일         개장일 Market   Name    code  \
# 0      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 1      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 2      2021-11-03  2021-11-03  ^KS11  카카오뱅크  323410
# 3      2021-10-18  2021-10-18  ^KS11  카카오뱅크  323410
# 4      2021-10-12  2021-10-12  ^KS11  카카오뱅크  323410
# ...           ...         ...    ...    ...     ...
# 20288  2015-03-17  2015-03-17  ^KS11   사조산업  007160
# 20289  2015-06-12  2015-06-12  ^KS11  까뮤이앤씨  013700
# 20290  2015-06-01  2015-06-01  ^KQ11   서전기전  189860
# 20291  2015-03-17  2015-03-17  ^KQ11   서전기전  189860
# 20292  2014-07-14  2014-07-14  ^KQ11     협진  138360
#
#                                   Sector  adjusted_Close  report_TargetPrice  \
# 0                              은행 및 저축기관         59400.0                   0
# 1                              은행 및 저축기관         59400.0               81000
# 2                              은행 및 저축기관         59400.0               73000
# ...

# %%
df_final_mod.tail(50)
# Out:
#               작성일         개장일 Market         Name    code  \
# 20242  2021-02-02  2021-02-02  ^KQ11           핑거  163730
# 20243  2015-04-10  2015-04-10  ^KS11           한독  002390
# 20244  2018-04-13  2018-04-13  ^KQ11         한컴위드  054920
# 20245  2017-11-02  2017-11-02  ^KS11          다스코  058730
# 20246  2016-11-28  2016-11-28  ^KS11        한국프랜지  010100
# 20247  2015-08-17  2015-08-17  ^KQ11         인포바인  115310
# 20248  2016-11-28  2016-11-28  ^KS11       상신브레이크  041650
# 20249  2021-04-19  2021-04-19  ^KS11       교촌에프앤비  339770
# 20250  2014-12-09  2014-12-09  ^KQ11       텔콘RF제약  200230
# 20251  2019-08-02  2019-08-02  ^KQ11       한국바이오젠  318000
# 20252  2020-06-30  2020-06-30  ^KQ11  브릿지바이오테라퓨틱스  288330
# 20254  2021-07-07  2021-07-07  ^KQ11           대원  007680
# 20255  2021-02-15  2021-02-15  ^KS11         삼영화학  003720
# 20256  2015-12-09  2015-12-09  ^KQ11        덕신하우징  090410
# 20257  2014-11-10  2014-11-10  ^KS11           신원  009270
# ...

# %%
len(df_final_mod.columns)
# Out:
# 24

# %%
df_final_mod[df_final_mod['1Year_return'].notnull()]
# Out:
#               작성일         개장일 Market   Name    code  \
# 70     2020-11-11  2020-11-11  ^KS11  삼성SDI  006400
# 71     2020-10-28  2020-10-28  ^KS11  삼성SDI  006400
# 72     2020-10-28  2020-10-28  ^KS11  삼성SDI  006400
# 73     2020-10-28  2020-10-28  ^KS11  삼성SDI  006400
# 74     2020-10-28  2020-10-28  ^KS11  삼성SDI  006400
# ...           ...         ...    ...    ...     ...
# 20288  2015-03-17  2015-03-17  ^KS11   사조산업  007160
# 20289  2015-06-12  2015-06-12  ^KS11  까뮤이앤씨  013700
# 20290  2015-06-01  2015-06-01  ^KQ11   서전기전  189860
# 20291  2015-03-17  2015-03-17  ^KQ11   서전기전  189860
# 20292  2014-07-14  2014-07-14  ^KQ11     협진  138360
#
#                                   Sector  adjusted_Close  report_TargetPrice  \
# 70                        일차전지 및 축전지 제조업        512000.0              560000
# 71                        일차전지 및 축전지 제조업        430000.0              550000
# 72                        일차전지 및 축전지 제조업        430000.0              560000
# ...
