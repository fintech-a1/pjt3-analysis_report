# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus']= False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_csv('sell_anal.csv', index_col=0)
df.head()
# Out:
#           작성일         개장일 Market   Name  code          Sector  adjusted_Close  \
# 0  2020-11-11  2020-11-11  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업        512000.0
# 1  2020-10-28  2020-10-28  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업        430000.0
# 2  2020-10-28  2020-10-28  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업        430000.0
# 3  2020-10-28  2020-10-28  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업        430000.0
# 4  2020-10-28  2020-10-28  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업        430000.0
#
#    report_TargetPrice  Index_return_6  Index_return_1Y  6month_return_index  \
# 0              560000        0.307108         0.176618            -0.033670
# 1              550000        0.371929         0.283248             0.230397
# 2              560000        0.371929         0.283248             0.230397
# 3              590000        0.371929         0.283248             0.230397
# 4              480000        0.371929         0.283248             0.230397
#
# ...

# %%
fig, axes = plt.subplots(1,3, figsize=(15,5))
df['6month_return'].plot(kind='hist', ax = axes[0])
df['6month_log_return'].plot(kind='hist', ax = axes[1])
np.log1p(df['6month_return']).plot(kind='hist', ax = axes[2])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig, axes = plt.subplots(1,3, figsize=(15,5))
df['1Year_return'].plot(kind='hist', ax = axes[0])
df['1Year_log_return'].plot(kind='hist', ax = axes[1])
np.log1p(df['1Year_return']).plot(kind='hist', ax = axes[2])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %%
df.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %%
df.groupby('투자의견')['1Year_return'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %%
df.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %%
# 연도별 데이터프레임
for i in range(2011, 2022):
    globals()['df_{}'.format(i)] = df[pd.to_datetime(df['작성일']).dt.year == i]

# %%
df_2011.head()
# Out:
#             작성일         개장일 Market   Name  code          Sector  \
# 973  2011-12-29  2011-12-29  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업
# 974  2011-12-21  2011-12-21  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업
# 975  2011-12-09  2011-12-09  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업
# 976  2011-12-07  2011-12-07  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업
# 977  2011-12-01  2011-12-01  ^KS11  삼성SDI  6400  일차전지 및 축전지 제조업
#
#      adjusted_Close  report_TargetPrice  Index_return_6  Index_return_1Y  \
# 973        133500.0              190000       -0.004343         0.093830
# 974        135500.0              190000        0.023425         0.081741
# 975        140000.0              170000       -0.038885         0.044113
# 976        139500.0              160000       -0.071006         0.015734
# 977        139000.0              170000       -0.034584         0.008726
#
#      6month_return_index  6month_return  6month_log_return  \
# 973             0.116703       0.112360           0.106483
# ...

# %% [markdown]
# ### 2011년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2011.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2011.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2011.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2011.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2012년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2012.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2012.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2012.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2012.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2013년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2013.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2013.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2013.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2013.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2014년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2014.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2014.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2014.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2014.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2015년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2015.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2015.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2015.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2015.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2016년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2016.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2016.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2016.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2016.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2017년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2017.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2017.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2017.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2017.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2018년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2018.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2018.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2018.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2018.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2019년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2019.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2019.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2019.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2019.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %% [markdown]
# ### 2020년 6개월 / 1년 수익률

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2020.groupby('투자의견')['6month_return'].mean().plot(kind = 'bar', ax=axes[0])
df_2020.groupby('투자의견')['1Year_return'].mean().plot(kind='bar', ax=axes[1])
df_2020.groupby('투자의견')['6month_return_index'].mean().plot(kind='bar', ax=axes[2])
df_2020.groupby('투자의견')['1Year_return_index'].mean().plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='투자의견'>

# %%
sns.jointplot(x = df.투자의견, y = df['6month_return'], data=df)

# %%
a=df[df['6month_return'] > 1]

# %%
a.투자의견.value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x = df.투자의견, y = df['1Year_return'], data=df)

# %%
df[df['1Year_return'] > 10]
# Out:
#                작성일         개장일 Market    Name    code                 Sector  \
# 79082   2020-03-24  2020-03-24  ^KQ11  데브시스터즈  194480         소프트웨어 개발 및 공급업
# 79513   2019-10-15  2019-10-15  ^KQ11      씨젠   96530  의료용품 및 기타 의약 관련제품 제조업
# 79514   2019-10-08  2019-10-08  ^KQ11      씨젠   96530  의료용품 및 기타 의약 관련제품 제조업
# 101969  2019-08-28  2019-08-28  ^KQ11    알테오젠  196170        자연과학 및 공학 연구개발업
# 133673  2019-09-09  2019-09-09  ^KQ11    알테오젠  196170        자연과학 및 공학 연구개발업
# 135000  2019-07-30  2019-07-30  ^KS11    신풍제약   19170                의약품 제조업
#
#         adjusted_Close  report_TargetPrice  Index_return_6  Index_return_1Y  \
# 79082           4460.0                   0        0.850291         0.985470
# 79513          11484.0               34000       -0.054947         0.331911
# 79514          10855.0               38000       -0.098204         0.368660
# 101969         10737.0                   0        0.060358         0.387295
# ...

# %%
a=df[df['1Year_return'] > 1]

# %%
a.투자의견.value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
a=df[df['1Year_return'] > 2]
a.투자의견.value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
fig= plt.figure(figsize=(10,5))
sns.scatterplot(x = df['6month_return'], y= df['1Year_return'], data =df , hue='투자의견')
# Out:
# <AxesSubplot:xlabel='6month_return', ylabel='1Year_return'>

# %%
sns.scatterplot(x = df['Index_return_6'], y= df['Index_return_1Y'], data =df )
# Out:
# <AxesSubplot:xlabel='Index_return_6', ylabel='Index_return_1Y'>

# %%
sns.scatterplot(x = df['6month_return_index'], y= df['1Year_return_index'], data =df , hue='투자의견')
# Out:
# <AxesSubplot:xlabel='6month_return_index', ylabel='1Year_return_index'>

# %%
df[df['Index_return_6'] > 0.7]
# Out:
#                작성일         개장일 Market     Name    code                 Sector  \
# 4104    2020-03-23  2020-03-23  ^KQ11       디오   39840             의료용 기기 제조업
# 6331    2020-03-16  2020-03-16  ^KQ11     인터로조  119610             의료용 기기 제조업
# 7767    2020-03-24  2020-03-24  ^KQ11   아프리카TV   67160         소프트웨어 개발 및 공급업
# 24433   2020-03-18  2020-03-18  ^KQ11     에스티팜  237690                의약품 제조업
# 35341   2020-03-24  2020-03-24  ^KQ11  CJ프레시웨이   51500         음·식료품 및 담배 도매업
# ...            ...         ...    ...      ...     ...                    ...
# 132891  2020-03-17  2020-03-17  ^KQ11   도이치모터스   67990                자동차 판매업
# 133430  2020-03-18  2020-03-18  ^KQ11    오이솔루션  138080         통신 및 방송 장비 제조업
# 133494  2020-03-16  2020-03-16  ^KQ11    서부T&D    6730       일반 및 생활 숙박시설 운영업
# 134476  2020-03-17  2020-03-17  ^KQ11      머큐리  100590         통신 및 방송 장비 제조업
# 134971  2020-03-18  2020-03-18  ^KQ11   바이오솔루션   86820  기초 의약물질 및 생물학적 제제 제조업
#
# ...

# %%
df.groupby('제공출처')['6month_return_index'].mean().sort_values()[20:].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %%
df.groupby('제공출처')['1Year_return_index'].mean().sort_values()[20:].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %%
df.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %%
df.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2011년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2011.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2011.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2011.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2011.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2012년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2012.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2012.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2012.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2012.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2013년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2013.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2013.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2013.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2013.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2014년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2014.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2014.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2014.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2014.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2015년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2015.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2015.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2015.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2015.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2016년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2016.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2016.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2016.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2016.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2017년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2017.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2017.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2017.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2017.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2018년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2018.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2018.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2018.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2018.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2019년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2019.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2019.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2019.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2019.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %% [markdown]
# ### 2020년 제공출처별 6개월 / 1년 수익률 예측

# %%
fig, axes = plt.subplots(1,4, figsize=(15,5))
df_2020.groupby('제공출처')['6month_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[0])
df_2020.groupby('제공출처')['1Year_return_index'].mean().sort_values()[-10:].plot(kind='bar', ax=axes[1])
df_2020.groupby('제공출처')['6month_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[2])
df_2020.groupby('제공출처')['1Year_return_index'].mean().sort_values()[:10].plot(kind='bar', ax=axes[3])
# Out:
# <AxesSubplot:xlabel='제공출처'>

# %%
(df.groupby('제공출처')['1Year_return_index'].mean() + df.groupby('제공출처')['6month_return_index'].mean()).sort_values()[25:].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='제공출처'>

# %%
fig, axes = plt.subplots(2,1 ,figsize=(10,5))
df['Index_return_6'].plot(ax = axes[0])
df['6month_return'].plot(ax=axes[1])
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.histplot(data = df, x = (df['6month_return_index']), bins=60, ax = axes[0])
sns.histplot(data = df, x = (df['1Year_return_index']), bins=60, ax = axes[1])
# Out:
# <AxesSubplot:xlabel='1Year_return_index', ylabel='Count'>

# %%
fig, axes = plt.subplots(1, 2, figsize = (10,5))
sns.rugplot( x='6month_return', data=df, height=1, ax = axes[1])
sns.rugplot( x='6month_return_index', data=df, height=1,ax = axes[0])
# Out:
# <AxesSubplot:xlabel='6month_return_index'>

# %%
fig, axes = plt.subplots(1, 2, figsize = (10,5))
sns.rugplot( x='1Year_return', data=df, height=1, ax = axes[1])
sns.rugplot( x='1Year_return_index', data=df, height=1,ax = axes[0])
# Out:
# <AxesSubplot:xlabel='1Year_return_index'>
